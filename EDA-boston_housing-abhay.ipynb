# %%
import pandas as pd 
import numpy as np 
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import os
from pandas import read_csv
column=['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV']
df=pd.read_csv('/Users/abhaylal/Desktop/CS/Housing.csv',header=None, names=column)
df.dropna(inplace = True) #removes null values from rows and columns
print("Data for Boston Housing")
df.head(11)#show the first 11 rows in table
# Out:
# Data for Boston Housing
#        CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD  TAX  \
# 0   0.00632  18.0   2.31     0  0.538  6.575   65.2  4.0900    1  296
# 1   0.02731   0.0   7.07     0  0.469  6.421   78.9  4.9671    2  242
# 2   0.02729   0.0   7.07     0  0.469  7.185   61.1  4.9671    2  242
# 3   0.03237   0.0   2.18     0  0.458  6.998   45.8  6.0622    3  222
# 4   0.06905   0.0   2.18     0  0.458  7.147   54.2  6.0622    3  222
# 5   0.02985   0.0   2.18     0  0.458  6.430   58.7  6.0622    3  222
# 6   0.08829  12.5   7.87     0  0.524  6.012   66.6  5.5605    5  311
# 7   0.14455  12.5   7.87     0  0.524  6.172   96.1  5.9505    5  311
# 8   0.21124  12.5   7.87     0  0.524  5.631  100.0  6.0821    5  311
# 9   0.17004  12.5   7.87     0  0.524  6.004   85.9  6.5921    5  311
# 10  0.22489  12.5   7.87     0  0.524  6.377   94.3  6.3467    5  311
#
#     PTRATIO       B  LSTAT  MEDV
# 0      15.3  396.90   4.98  24.0
# 1      17.8  396.90   9.14  21.6
# ...

# %% [markdown]
# crim
# per capita crime rate by town.
#
# zn
# proportion of residential land zoned for lots over 25,000 sq.ft.
#
# indus
# proportion of non-retail business acres per town.
#
# chas
# Charles River dummy variable (= 1 if tract bounds river; 0 otherwise).
#
# nox
# nitrogen oxides concentration (parts per 10 million).
#
# rm
# average number of rooms per dwelling.
#
# age
# proportion of owner-occupied units built prior to 1940.
#
# dis
# weighted mean of distances to five Boston employment centres.
#
# rad
# index of accessibility to radial highways.
#
# tax
# full-value property-tax rate per \$10,000.
#
# ptratio
# pupil-teacher ratio by town.
#
# black
# 1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town.
#
# lstat
# lower status of the population (percent).
#
# medv
# median value of owner-occupied homes in \$1000s.

# %% [markdown]
# # Exploratory Data Analysis:-

# %%
df.info()#give complete information about dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    int64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    int64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 59.3 KB

# %%
df.describe()#describe the dataset
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
df.MEDV.describe()#medv is the target variable with median value of owner-occupied homes in \$1000s.
# Out:
# count    506.000000
# mean      22.532806
# std        9.197104
# min        5.000000
# 25%       17.025000
# 50%       21.200000
# 75%       25.000000
# max       50.000000
# Name: MEDV, dtype: float64

# %% [markdown]
# # SCATTERPLOTS WITH RESPECT TO MEDV(TARGET VARIABLE)

# %%
fig, ax = plt.subplots(figsize=(10,10))
ax.scatter(df.loc[:, "CRIM"], df.loc[:, "MEDV"])
plt.xlabel("Per capita crime rate")
plt.ylabel("Median Value")
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,10))
ax.scatter(df.loc[:, "ZN"], df.loc[:, "MEDV"])
plt.xlabel("Proportion of residential land zoned for lots over 25,000 sq.ft.")
plt.ylabel("Median value") 
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,10))
ax.scatter(df.loc[:,"NOX"], df.loc[:, "MEDV"])
plt.xlabel("Nitric Oxides Concentration")
plt.ylabel("Median Value")
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,10))
ax.scatter(df.loc[:,"RM"], df.loc[:, "MEDV"])
plt.xlabel("Average rooms per dwelling")
plt.ylabel("Median Value")
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,10))
ax.scatter(df.loc[:,"DIS"], df.loc[:, "MEDV"])
plt.xlabel("Average distance to work")
plt.ylabel("Median Value")
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,10))
ax.scatter(df.loc[:,"RAD"], df.loc[:, "MEDV"])
plt.xlabel("Accessibility to highways")
plt.ylabel("Median Value")
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,10))
ax.scatter(df.loc[:,"TAX"], df.loc[:, "MEDV"])
plt.xlabel("Tax rate per $10,000")
plt.ylabel("Median Value")
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,10))
ax.scatter(df.loc[:,"LSTAT"], df.loc[:, "MEDV"])
plt.xlabel("Population % of lower working class")
plt.ylabel("Median Value")
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,10))
ax.scatter(df.loc[:, "INDUS"], df.loc[:, "MEDV"])
plt.xlabel("Proportion of non-retail business acres per town")
plt.ylabel("Median Value")
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,10))
ax.scatter(df.loc[:, "CHAS"], df.loc[:, "MEDV"])
plt.xlabel("0 = tract does not bound river                       1= tract bounds river")
plt.ylabel("Median Value")
plt.show()

# %%
#plotting histograms for all columns
rows = 2
cols = 7
fig, ax = plt.subplots(nrows= rows, ncols= cols, figsize = (15,10))
col = df.columns#storing columns from dataset to col
c= 0
for i in range(rows):
    for j in range(cols):
        sns.histplot(df[col[c]], ax = ax[i][j]) #plotting histogram
        c+=1
plt.tight_layout()#to give padding and adjust space between subplot parameters
plt.show()

# %%
corrmat = df.corr()#correlation matrix of full data
corrmat#show correlation matrix
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247  0.352734
# ZN      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# INDUS    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# CHAS    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# NOX      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# RM      -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# AGE      0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# DIS     -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# RAD      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# TAX      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# PTRATIO  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# ...

# %%
fig, ax = plt.subplots(figsize = (20, 16))
sns.heatmap(corrmat, annot = True)#using seaborn to make a heatmap
plt.show()
